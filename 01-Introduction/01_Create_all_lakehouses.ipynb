# %%
# %sql
CREATE CATALOG IF NOT EXISTS levkiwi_lakehouse MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragexyfbclfd2i7hu.dfs.core.windows.net/744986589015891';

# %%
# %sql
CREATE CATALOG IF NOT EXISTS prenomnom_lakehouse MANAGED LOCATION 'abfss://unity-catalog-storage@dbstoragexyfbclfd2i7hu.dfs.core.windows.net/744986589015891';
